# %% [markdown]
# <a href="https://colab.research.google.com/github/IzissS2/INTED_2025/blob/main/Iziss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello collab!')
# Out:
# hello collab!

# %% [markdown]
# # Nova seção

# %%
# a = b + c peça dois números e exiba a soma     (1)

b = int(input('Digite o primeiro número:'))
c = int(input('Digite o segundo número:'))
print("a=",b+c)
# Out:
# Digite o primeiro número:4
# Digite o segundo número:5
# a= 9

# %%
#Peça dois números e exiba o produto (multiplicação).     (2)

b = int(input('Digite o primeiro número:'))
c = int(input('Digite o segundo número:'))
print("a=",b*c)
# Out:
# Digite o primeiro número:4
# Digite o segundo número:5
# a= 20

# %%
#Peça três números e exiba a média aritmética.     (3)

b = int(input('Digite o primeiro número:'))
c = int(input('Digite o segundo número:'))
d = int(input('Digite o terceiro número:'))
print("a=",(b+c+d)/3)
# Out:
# Digite o primeiro número:4
# Digite o segundo número:8
# Digite o terceiro número:12
# a= 8.0

# %%
#Peça um número e mostre o dobro dele.     (4)

b = int(input('Digite o primeiro número:'))
print('a=',2*b)

# %%
#Peça um número e mostre o quadrado dele.     (5)

b = int(input('Digite o primeiro número:'))
print('a=', b ** 2)

# %%
#Peça dois números e exiba o resto da divisão entre eles.     (6)

b = int(input('Digite o primeiro número:'))
c = int(input('Digite o primeiro número:'))
print('a=',b%c)

# %%
#Peça um número e mostre seu valor absoluto.     (7)

b = int(input('Digite o primeiro número:'))
print(abs(b))

# %%
#Peça dois números e mostre a divisão inteira.     (8)

b = int(input('Digite o primeiro número:'))
c = int(input('Digite o primeiro número:'))
print('a=',b//c)

# %%
#Peça dois números e mostre a soma e o módulo da diferença.     (9)

a = -10
b = 5
print('soma:',a+b,'módulo',abs(a-b))

# %%
#Peça um número e mostre o resultado de n % 2 == 0.     (10)

a = int(input('Digite o primeiro número:'))
print(a % 2 == 0)

# %%
# Peça dois números e mostre o resultado de a > b.     (11)

a = int(input('Digite o primeiro número:'))
b = int(input('Digite o primeiro número:'))
print(a > b)

# %%
#Peça dois números e mostre o resultado de a == b.     (12)

a = int(input('Digite o primeiro número:'))
b = int(input('Digite o primeiro número:'))
print(a == b)

# %%
#Peça dois números e exiba o resultado de (a + b) > 100.     (13)

a = int(input('Digite o primeiro número:'))
b = int(input('Digite o primeiro número:'))
print((a + b) > 100)

# %%
#Peça a idade e exiba o resultado de idade >= 18.     (14)
a = int(input('Digite o primeiro número:'))

print(a >= 18)

# %%
#Peça um número e exiba o resultado de n % 5 == 0.     (15)

a = int(input('Digite o primeiro número:'))

print(a % 5 == 0 )

# %%
#Peça dois números e exiba o resultado de (a > 0) and (b > 0).     (16)

a = int(input('Digite o primeiro número:'))
b = int(input('Digite o primeiro número:'))
print((a > 0) and (b > 0))

# %%
#Peça dois números e exiba (a < 0) or (b < 0).     (17)

a = int(input('Digite o primeiro número:'))
b = int(input('Digite o primeiro número:'))
print((a < 0) and (b < 0))

# %%
#Peça três números e exiba (a < b) and (b < c).     (18)

a = int(input('Digite o primeiro número:'))
b = int(input('Digite o primeiro número:'))
c = int(input('Digite o primeiro número:'))
print((a < b) and (b < c))

# %%
#Peça três números e exiba o resultado de (a + b > c) and (a + c > b) and (b + c > a).     (19)

a = int(input('Digite o primeiro número:'))
b = int(input('Digite o primeiro número:'))
c = int(input('Digite o primeiro número:'))
print((a + b > c) and (a + c > b) and (b + c > a))

# %%
#Peça dois números e exiba o resultado de (a * b) % 2 == 0.     (20)

a = int(input('Digite o primeiro número:'))
b = int(input('Digite o primeiro número:'))
print((a * b) % 2 == 0)

# %% [markdown]
# # Nova seção

# %%
#1 Peça um número e informe se ele é maior que 10.

numero = int(input('Digite o primeiro número:'))
if numero > 10: print("O número é maior que 10.")
if numero < 10: print("O número é menor que 10.")

# %%
#2 Peça um número inteiro e informe se ele é par. Crie um algoritmo em Python que verifique se o número é divisível por 2.

if int(input('Digite o primeiro número:')) %2==0: print("Par.")
else: print("Impar.")
# Out:
# Digite o primeiro número:2
# Par.

# %%
#3 Peça um nome e informe se ele contém a letra "a". Crie um algoritmo em Python que faça essa verificação.

nome = (input('Digite nome.:'))
if "a" in nome : print("O nome possui a letra a.")
else: print("O nome não possui a.")
# Out:
# Digite nome.:Izis
# O nome não possui a.

# %%
#4 Peça um número e informe se ele é múltiplo de 5. Crie um algoritmo em Python que verifique se o número é divisível por 5.

numero = int(input('Digite o primeiro número:'))
if numero%5==0:
  print("O número é múltiplo de 5.")
else :
  print("O número não é múltiplo de 5.")

# %%
#5 Peça a temperatura atual e informe se está quente (acima de 30°C) ou frio (30°C ou menos). Crie um algoritmo em Python para essa verificação.

temperatura = int(input('Digite a temperatura atual:'))
if temperatura > 30:
  print ("A temperatura está quente.")
else:
  print ("A temperatura está fria.")

# %%
#6 Peça ao usuário para digitar "S" para continuar ou "N" para sair e informe a ação correspondente. Crie um algoritmo em Python que faça essa validação e exiba a mensagem correta.

texto = (input('Digite S para continuar e N para sair:'))
if texto == "S":
  print("Continuar.")
elif texto == "N":
  print("Sair.")

# %%
#7 Peça um número e informe se ele é negativo, zero ou positivo. Crie um algoritmo em Python para classificar o número.

numero = int(input('Digite o número:'))
if numero > 0:
  print("O número é positivo.")
elif numero < 0:
  print("O número é negativo.")
else:
 print("O número é zero.")

# %%
#8 Peça um número de 1 a 7 e informe o dia da semana correspondente. Crie um algoritmo em Python que associe o número ao dia correto.

numero = int(input('Digite o número de 1 a 7:'))

if numero == 1:
  print("Segunda-feira")
elif numero == 2:
  print("Terça-feira")
elif numero == 3:
  print("Quarta-feira")
elif numero == 4:
  print("Quinta-feira")
elif numero == 5:
  print("Sexta-feira")
elif numero == 6:
  print("Sábado")
elif numero == 7:
  print("Domingo")
else:
  print("nao tem")

# %%
#9 Peça um ano e informe se ele é bissexto. Crie um algoritmo em Python que verifique se o ano é divisível por 4 e não por 100, exceto se também for divisível por 400.

ano = int(input('Digite um ano:'))
if ano%4 == 0:
  print("Ano bissexto.")
else:
  print("Não é bissexto.")
# Out:
# Digite um ano:1987
# Não é bissexto.

# %%
#10 Peça a quantidade de horas trabalhadas e o valor por hora. Se trabalhou até 40 horas, calcule o salário normalmente (horas × valor por hora). Se trabalhou mais de 40 horas, as horas extras devem ter um adicional de 50% (horas extras × valor por hora × 1.5). Crie um algoritmo em Python que realize esse cálculo corretamente.

horas_trabalhadas = float(input("Digite a quantidade de horas trabalhadas: "))
valor_por_hora = float(input("Digite o valor por hora: "))

if horas_trabalhadas <= 40:
    salario = horas_trabalhadas * valor_por_hora
else:
    salario_base = 40 * valor_por_hora
    horas_extras = horas_trabalhadas - 40
    valor_horas_extras = horas_extras * valor_por_hora * 1.5
    salario = salario_base + valor_horas_extras

print(f"O salário total é: R${salario:.2f}")
# Out:
# Digite a quantidade de horas trabalhadas: 24
# Digite o valor por hora: 10
# O salário total é: R$240.00

# %% [markdown]
# # Nova seção
